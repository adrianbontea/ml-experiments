# %%
import matplotlib.pyplot as plt
import numpy as np

print("This is a Jupyter notebook rendering test on Github!")

X = 2 * np.random.uniform(1, 5, (100, 1))
y = 4 + 3 * X + np.random.uniform(1, 5, (100, 1))

plt.plot(X, y, ".")
plt.show()
# Out:
# This is a Jupyter notebook rendering test on Github!
